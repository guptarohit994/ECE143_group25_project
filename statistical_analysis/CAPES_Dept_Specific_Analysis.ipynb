# %%
# fully expand cells
from IPython.core.display import display, HTML
import numpy as np
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
csv_file_path = "cape/cape_CSE_auto.csv"
df = csv_to_dataframe(csv_file_path, True)
class_df = general_to_conditioned_df(df, "Course")
prof_df = general_to_conditioned_df(df,"Instructor")

for criteria in ["RcmndClass", "StudyHrs/wk", "AvgGradeReceived"]:
    ymin = min(class_df[criteria])
    ymax = max(class_df[criteria])
    ax = class_df.sort_values([criteria]).plot.bar(x="Course",y=criteria,figsize=(35,10), ylim=(ymin-1, ymax))

for criteria in ["RcmndInstr", "StudyHrs/wk", "AvgGradeReceived"]:
    ymin = min(prof_df[criteria])
    ymax = max(prof_df[criteria])
    ax =  prof_df[prof_df.EvalsMade > 400].sort_values([criteria]).plot.bar(x="Instructor",y=criteria,figsize=(40,10), ylim=(ymin-1, ymax))
# Out:
# /data7/drone_machinelearning/anaconda3/envs/pytorch11_py37/lib/python3.7/site-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 25.0 100.0
# 0.7681521739130435 16.589354066985646
# 2.29 3.950248447204969

# %%
CSE_term_df = general_to_conditioned_df(CSE_df, "Term")
dataframe = CSE_term_df
for criteria in ["RcmndInstr", "StudyHrs/wk", "AvgGradeReceived"]:
    ymin = min(dataframe[criteria])
    ymax = max(dataframe[criteria])
    ax = dataframe[CSE_term_df["Term"].apply(lambda x: x[:2] not in ["S1", "S2"])][::-1].plot.bar(x="Term",y=criteria,figsize=(35,10), ylim=(ymin-1, ymax))
# Out:
# /data7/drone_machinelearning/anaconda3/envs/pytorch11_py37/lib/python3.7/site-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dataframe = CSE_term_df
for criteria in ["RcmndInstr", "StudyHrs/wk", "AvgGradeReceived"]:
    ymin = min(dataframe[criteria])
    ymax = max(dataframe[criteria])
    ax = dataframe[CSE_term_df["Term"].apply(lambda x: x[:2] not in ["S1", "S2"])][::-1].plot.bar(x="Term",y=criteria,figsize=(35,10), ylim=(ymin-1, ymax))

# %%
for criteria in ["RcmndClass", "StudyHrs/wk", "AvgGradeReceived"]:
    ymin = min(class_df[criteria])
    ymax = max(class_df[criteria])
    ax = class_df.sort_values([criteria]).plot.bar(x="Course",y=criteria,figsize=(35,10), ylim=(ymin-1, ymax))

# %%
for criteria in ["RcmndInstr", "StudyHrs/wk", "AvgGradeReceived"]:
    ymin = min(prof_df[criteria])
    ymax = max(prof_df[criteria])
    print(ymin, ymax)
    ax =  prof_df[prof_df.EvalsMade > 400].sort_values([criteria]).plot.bar(x="Instructor",y=criteria,figsize=(40,10), ylim=(ymin-1, ymax))
# Out:
# 14.867368421052632 100.0
# 3.4699999999999998 13.48
# 1.56 3.5841813602015113
